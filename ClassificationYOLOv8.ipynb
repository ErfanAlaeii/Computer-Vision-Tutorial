# %%
import zipfile
import os

zip_path = '/content/datasets.zip'


extract_path = '/content/'
os.makedirs(extract_path, exist_ok=True)


with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# %% [markdown]
# ![photo_2024-06-06_13-13-35.jpg](data:image/jpeg;base64,...)

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.6/779.6 kB 11.0 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
from IPython.display import Image

# %%
# %cd '/content'
# Out:
# /content

# %%
# !pwd
# Out:
# /content

# %%
# !yolo task=classify mode=train model=yolov8n-cls.pt data='/content/datasets' epochs=100 imgsz=64
# Out:
# ...
# 100% 5.30M/5.30M [00:00<00:00, 20.6MB/s]
# Ultralytics YOLOv8.2.28 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !pwd
# Out:
# /content

# %%
# !yolo classify mode=val model='/content/runs/classify/train/weights/best.pt' data='/content/datasets'
# Out:
# Ultralytics YOLOv8.2.28 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-cls summary (fused): 73 layers, 1437442 parameters, 0 gradients, 3.3 GFLOPs
# train: /content/datasets/train... found 216 images in 2 classes ✅
# val: /content/datasets/val... found 44 images in 2 classes ✅
# test: None...
# val: Scanning /content/datasets/val... 44 images, 0 corrupt: 100% 44/44 [00:00<?, ?it/s]
#                classes   top1_acc   top5_acc: 100% 3/3 [00:00<00:00,  3.30it/s]
#                    all      0.977          1
# Speed: 0.0ms preprocess, 13.5ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to runs/classify/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
Image('/content/runs/classify/val/confusion_matrix.png')

# %%
Image('/content/runs/classify/val/confusion_matrix_normalized.png')

# %%
# !yolo classify predict model='/content/runs/classify/train/weights/best.pt' source='https://www.bornfree.org.uk/wp-content/uploads/2023/09/cropped-Lion-species-hero-c-George-Logan.jpg'
# Out:
# Ultralytics YOLOv8.2.28 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-cls summary (fused): 73 layers, 1437442 parameters, 0 gradients, 3.3 GFLOPs
#
# ...
# 100% 221k/221k [00:00<00:00, 243kB/s]
# image 1/1 /content/cropped-Lion-species-hero-c-George-Logan.jpg: 64x64 Lion 1.00, Tiger 0.00, 4.5ms
# Speed: 27.9ms preprocess, 4.5ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# Results saved to runs/classify/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
Image('/content/runs/classify/predict2/cropped-Lion-species-hero-c-George-Logan.jpg')

# %%
# !yolo classify predict model='/content/runs/classify/train/weights/best.pt' source='https://wildlifesos.org/wp-content/uploads/2022/07/Tiger_Shirina.jpg'
# Out:
# Ultralytics YOLOv8.2.28 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-cls summary (fused): 73 layers, 1437442 parameters, 0 gradients, 3.3 GFLOPs
#
# ...
# 100% 785k/785k [00:00<00:00, 3.56MB/s]
# image 1/1 /content/Tiger_Shirina.jpg: 64x64 Tiger 1.00, Lion 0.00, 4.8ms
# Speed: 31.6ms preprocess, 4.8ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# Results saved to runs/classify/predict4
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
Image('/content/runs/classify/predict4/Tiger_Shirina.jpg')
